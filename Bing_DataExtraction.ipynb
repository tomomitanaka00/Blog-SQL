# %%
#Bing's first attempt

# Define the data
data = [
    {"Name": "Mark", "Birthday": "October 1", "Hobby": "Nature", "Species": "Cat"},
    {"Name": "Lucy", "Birthday": "October 31", "Hobby": "Education", "Species": "Deer"},
    {"Name": "Richard", "Birthday": "January 1", "Hobby": "Play", "Species": "Cat"},
    {"Name": "Matt", "Birthday": "September 29", "Hobby": "Music", "Species": "Squirrel"},
    {"Name": "Max", "Birthday": "April 16", "Hobby": "Play", "Species": "Bear Cub"}
]

# Import pandas for data analysis
import pandas as pd

# Convert the data into a pandas DataFrame
df = pd.DataFrame(data)

# Now you can perform various analyses on the data
# For example, to get the count of each species:
species_counts = df['Species'].value_counts()
print(species_counts)

# Or to get all villagers with the 'Play' hobby:
play_hobby_villagers = df[df['Hobby'] == 'Play']
print(play_hobby_villagers)

# %%
#Bing's second attempt

import re
import pandas as pd

# Define the text
text = """
Mark is a smug cat villager. Mark has the nature hobby. His birthday is October 1.
Lucy is a peppy deer villager. Lucy has the education hobby . Her birthday is October 31.
Richard is a lazy cat villager. Richard was the first villager created, and his January 1 birthday came as a result of that. Richard has the play hobby.
Matt is a smug squirrel villager. Matt has the music hobby and may sing anywhere without the need of a stereo. His birthday is September 29.
Max is a lazy bear cub villager . Max has the play hobby. His birthday is April 16 .
"""

# Define the regular expression pattern
pattern = r"(\w+) is a (\w+ \w+ \w+ villager). \w+ has the (\w+ hobby). His birthday is (\w+ \d+)."

# Use the 'findall' method to capture all matches
matches = re.findall(pattern, text)

# Convert the matches into a pandas DataFrame
df = pd.DataFrame(matches, columns=["Name", "Species", "Hobby", "Birthday"])

# Now you can perform various analyses on the data
# For example, to get the count of each species:
species_counts = df['Species'].value_counts()
print(species_counts)

# Or to get all villagers with the 'Play' hobby:
play_hobby_villagers = df[df['Hobby'] == 'Play hobby']
print(play_hobby_villagers)
# Out:
# Series([], Name: Species, dtype: int64)
# Empty DataFrame
# Columns: [Name, Species, Hobby, Birthday]
# Index: []

# %%
# code generated by Bing after requested debugging. 

import re
import pandas as pd

# Define the text
text = """
Mark is a smug cat villager. Mark has the nature hobby. His birthday is October 1.
Lucy is a peppy deer villager. Lucy has the education hobby . Her birthday is October 31.
Richard is a lazy cat villager. Richard was the first villager created, and his January 1 birthday came as a result of that. Richard has the play hobby.
Matt is a smug squirrel villager. Matt has the music hobby and may sing anywhere without the need of a stereo. His birthday is September 29.
Max is a lazy bear cub villager . Max has the play hobby. His birthday is April 16 .
"""

# Define the regular expression pattern
pattern = r"(\w+) is a (\w+ \w+ \w* villager). \w+ has the (\w+ hobby). \w+ birthday is (\w+ \d+)."

# Use the 'findall' method to capture all matches
matches = re.findall(pattern, text)

# Convert the matches into a pandas DataFrame
df = pd.DataFrame(matches, columns=["Name", "Species", "Hobby", "Birthday"])

# Now you can perform various analyses on the data
# For example, to get the count of each species:
species_counts = df['Species'].value_counts()
print(species_counts)

# Or to get all villagers with the 'Play' hobby:
play_hobby_villagers = df[df['Hobby'] == 'Play hobby']
print(play_hobby_villagers)
# Out:
# Series([], Name: Species, dtype: int64)
# Empty DataFrame
# Columns: [Name, Species, Hobby, Birthday]
# Index: []
